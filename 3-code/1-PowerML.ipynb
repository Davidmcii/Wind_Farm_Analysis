# %%
import pandas as pd
import numpy as np

import pylab as plt
import seaborn as sns

import matplotlib

# %%
def convtime(x):
    x=x.removesuffix(':00+00:00')
    x=x.replace('T',' ')
    return x

# %%
metmast=pd.read_csv('../1-input/4-metmast-training.csv', sep=';')

metmast

metmast['Timestamp']=metmast['Timestamp'].apply( lambda x:convtime(x))

metmast['Timestamp'] = pd.to_datetime(metmast['Timestamp'])

metmast.head()
# Out:
#             Timestamp  Min_Windspeed1  Max_Windspeed1  Avg_Windspeed1  \
# 0 2016-01-01 00:00:00             3.7             6.0             5.1
# 1 2016-01-01 00:10:00             4.1             6.0             5.1
# 2 2016-01-01 00:20:00             4.5             6.7             5.7
# 3 2016-01-01 00:30:00             5.1             7.0             6.3
# 4 2016-01-01 00:40:00             4.7             7.3             6.2
#
#    Var_Windspeed1  Min_Windspeed2  Max_Windspeed2  Avg_Windspeed2  \
# 0            0.21             3.8             6.0             5.1
# 1            0.09             4.1             6.0             5.2
# 2            0.26             4.4             6.8             5.8
# 3            0.11             5.1             7.1             6.4
# 4            0.27             4.9             7.4             6.3
#
#    Var_Windspeed2  Min_Winddirection2  ...  Anemometer1_CorrOffset  \
# 0            0.22               236.0  ...                       0
# 1            0.10               236.0  ...                       0
# 2            0.30               236.0  ...                       0
# 3            0.12               236.0  ...                       0
# 4            0.27               236.0  ...                       0
#
#    Anemometer2_Freq  Anemometer2_Offset  Anemometer2_CorrGain  \
# 0            0.0499                0.24                     1
# 1            0.0499                0.24                     1
# 2            0.0499                0.24                     1
# 3            0.0499                0.24                     1
# 4            0.0499                0.24                     1
#
#    Anemometer2_CorrOffset  DistanceAirPress  AirRessureSensorZeroOffset  \
# 0                       0                 0                         600
# 1                       0                 0                         600
# 2                       0                 0                         600
# 3                       0                 0                         600
# 4                       0                 0                         600
#
#    Anemometer1_Avg_Freq  Anemometer2_Avg_Freq  Pressure_Avg_Freq
# 0                    98                    99                418
# 1                    99                   101                418
# 2                   111                   113                418
# 3                   122                   125                418
# 4                   121                   123                417
#
# [5 rows x 41 columns]

# %%
signals=pd.read_csv('../1-input/5-signals-training.csv', sep=';')

signals

signals['Timestamp']=signals['Timestamp'].apply( lambda x:convtime(x))

metmast['Timestamp'] = pd.to_datetime(metmast['Timestamp'])
